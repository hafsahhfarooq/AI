# %%
from roboflow import Roboflow
rf = Roboflow(api_key="OzhutvjcP3sHh1XS3Trj")
project = rf.workspace("titulacin").project("person-detection-9a6mk")
version = project.version(16)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import cv2
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image

# %%
from ultralytics import YOLO

# Load the model (choose a pre-trained model, e.g., 'yolov8n')
model = YOLO('yolov8n.pt')

# Train the model on your dataset
model.train(data=r'C:\Person-detection-16\data.yaml', epochs=10, imgsz=640, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.63 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.60  Python-3.12.7 torch-2.5.1+cpu CPU (AMD Ryzen 7 3700U with Radeon Vega Mobile Gfx)
# ...

# %%
results = model(r'C:\Person-detection-16\test\images', save=True, project='C:/Person-detection-16/test/images/Result', name='test_run', conf=0.3)
# Out:
# image 1/5 C:\Person-detection-16\test\images\photo-1634985492349-8589a9255cbe_jpg.rf.4f36728b2a976d7e05846712482d7c2f.jpg: 640x640 11 Personas, 215.0ms
# image 2/5 C:\Person-detection-16\test\images\premium_photo-1661292128559-ec5206d3a05a_jpg.rf.1bd2bae0c61320527a41389ea21e225a.jpg: 640x640 1 Persona, 152.6ms
# image 3/5 C:\Person-detection-16\test\images\premium_photo-1661430807726-7f3aca78277a_jpg.rf.f2054612302c3645a3bd3bff77871ea1.jpg: 640x640 1 Persona, 157.5ms
# image 4/5 C:\Person-detection-16\test\images\premium_photo-1661483376273-ebce3f96a557_jpg.rf.97ce81f3227de3097209985d1a8b0510.jpg: 640x640 4 Personas, 152.5ms
# image 5/5 C:\Person-detection-16\test\images\premium_photo-1661484857459-7256e961205d_jpg.rf.aa543481948b8207eea51c7f7b46471d.jpg: 640x640 1 Persona, 149.5ms
# Speed: 6.2ms preprocess, 165.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Person-detection-16\test\images\Result\test_run

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.60  Python-3.12.7 torch-2.5.1+cpu CPU (AMD Ryzen 7 3700U with Radeon Vega Mobile Gfx)
# val: Scanning C:\Person-detection-16\valid\labels.cache... 1071 images, 44 backgrounds, 0 corrupt: 100%|██████████| 1071/1071 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 67/67 [03:56<00:00,  3.52s/it]
#                    all       1071       2293      0.787      0.683      0.768      0.481
# Speed: 3.7ms preprocess, 197.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\train162
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x0000027720198BC0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# ...

# %%
image_path = r'C:\Users\hafsa\anaconda3\envs\AI_Bootcamp\runs\detect\train16\results.png'
image = Image.open(image_path)
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
image_path = r'C:\Users\hafsa\anaconda3\envs\AI_Bootcamp\runs\detect\train16\confusion_matrix_normalized.png'
image = Image.open(image_path)
plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# # Model Evaluation Summary:
# - mAP@50: 76.8%
# - mAP@50-95: 48.1%
# - Precision: 78.7%
# - Recall: 68.3%
# - Inference Speed: 232ms per image (~4 FPS)

# %% [markdown]
# # Key Metrics:
#
# Precision (metrics/precision(B)):
# Value: 0.787
# Indicates that 78.7% of the predictions made by the model are correct (low false positives).
# Good: Precision above 0.75 is usually considered strong.
#
# Recall (metrics/recall(B)):
# Value: 0.683
# Shows that the model correctly identifies 68.3% of the actual positive instances (low false negatives).
# Moderate: While this is decent, improving recall could help the model detect more objects.
#
# mAP50 (metrics/mAP50(B)):
# Value: 0.768
# Mean Average Precision at 50% IoU threshold indicates that the model is detecting objects well with reasonable localization accuracy.
# Good: A value above 0.75 suggests effective performance at the baseline IoU threshold.
#
# mAP50-95 (metrics/mAP50-95(B)):
# Value: 0.481
# Measures the model's performance across multiple IoU thresholds (50% to 95%), capturing stricter localization criteria.
# Moderate: While typical, improvement in this metric can signify better object localization.
#
# Fitness:
# Value: 0.510
# A composite score derived from the other metrics. It's used to compare different models or training runs.
# Improving: A higher fitness value (>0.5) typically reflects balanced performance.
#
# Speed:
# Preprocessing: 4.27 ms
# Inference: 232.12 ms
# Postprocessing: 1.41 ms
# These times are acceptable depending on your hardware and task requirements.
